# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork817-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Clustering based Course Recommender System**

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# Previously, we have generated user profile vectors based on course ratings and genres.
#
# A user profile vector may look like a row vector in the following matrix, for example, we can see the Database column for user2 has a value 1 which means user2 is very interesting in courses related to the databases. With the user profile vectors generated, we can also easily compute the similarity among users based on their shared interests.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles.png)

# %% [markdown]
# Furthermore, we could perform clustering algorithms such as K-means or DBSCAN to group users with similar learning interests. For example, in the below user clusters, we have user clusters whom have learned courses related to machine learning, cloud computing, databases, and web development, etc.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles_clustering.png)

# %% [markdown]
# For each user group, we can come up with a list of popular courses. For example, for the machine learning user cluster/learning group, we can count the most frequently enrolled courses, which are very likely to be the most popular and good machine learning courses because they are enrolled by many users who are interested in machine learning.
#
# If we know a user belongs to the machine learning group, we may recommend the most enrolled courses to them and it is very likely the user will be interested in them.

# %% [markdown]
# Next in this lab, you will be implementing some clustering-based recommender system algorithms.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# * Perform k-means clustering on the original user profile feature vectors
# * Apply PCA (Principle Component Analysis ) on user profile feature vectors to reduce dimensions
# * Perform k-means clustering on the PCA transformed main components
# * Generate course recommendations based on other group members' enrollment history

# %% [markdown]
# ----

# %% [markdown]
# ## Prepare and setup lab environment

# %% [markdown]
# First install and import required libraries:

# %%
# %pip install scikit-learn
# %pip install seaborn
# %pip install pandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: scikit-learn in c:\users\fahad\appdata\roaming\python\python311\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\fahad\anaconda3\lib\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\fahad\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\fahad\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\fahad\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\fahad\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\fahad\anaconda3\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\fahad\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\fahad\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fahad\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\fahad\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\fahad\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\fahad\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fahad\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\fahad\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\fahad\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\fahad\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fahad\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\fahad\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# also set a random state
rs = 123

# %% [markdown]
# ### Load the user profile dataset

# %% [markdown]
# Let's first load the original user profile feature vectors:

# %%
# Importing the pandas library, which is commonly used for data manipulation and analysis
import pandas as pd

# Defining the URL of the CSV file containing user profiles
user_profile_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/user_profile.csv"

# Using pandas' read_csv function to read the CSV file from the specified URL into a DataFrame
user_profile_df = pd.read_csv(user_profile_url)

# Displaying the first few rows of the DataFrame to inspect its contents
user_profile_df.head()
# Out:
#    user  Database  Python  CloudComputing  DataAnalysis  Containers  \
# 0     2      52.0    14.0             6.0          43.0         3.0
# 1     4      40.0     2.0             4.0          28.0         0.0
# 2     5      24.0     8.0            18.0          24.0         0.0
# 3     7       2.0     0.0             0.0           2.0         0.0
# 4     8       6.0     0.0             0.0           4.0         0.0
#
#    MachineLearning  ComputerVision  DataScience  BigData  Chatbot     R  \
# 0             33.0             0.0         29.0     41.0      2.0  18.0
# 1             14.0             0.0         20.0     24.0      0.0   6.0
# 2             30.0             0.0         22.0     14.0      2.0  14.0
# 3              0.0             0.0          0.0      2.0      0.0   0.0
# 4              0.0             0.0          0.0      6.0      0.0   2.0
#
#    BackendDev  FrontendDev  Blockchain
# 0        34.0          9.0         6.0
# 1         6.0          0.0         2.0
# 2        26.0          4.0         6.0
# 3         0.0          0.0         0.0
# 4         0.0          0.0         0.0

# %%
user_profile_df.shape
# Out:
# (33901, 15)

# %% [markdown]
# we can then list the feature names, they are the user interested topics (course genres):

# %%
feature_names = list(user_profile_df.columns[1:])
feature_names
# Out:
# ['Database',
#  'Python',
#  'CloudComputing',
#  'DataAnalysis',
#  'Containers',
#  'MachineLearning',
#  'ComputerVision',
#  'DataScience',
#  'BigData',
#  'Chatbot',
#  'R',
#  'BackendDev',
#  'FrontendDev',
#  'Blockchain']

# %% [markdown]
# As we can see from the user profile dataset, we have about 33K unique users with interests in areas like ``Database``, ``Python``, ``CloudComputing``, etc. Then, let's check the  summary statistics for each feature.

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  33901.000000  33901.000000    33901.000000  33901.000000
# mean   1.064064e+06      5.518569      3.493791        2.307100      3.624701
# std    4.972578e+05      7.611941      4.227254        3.841858      4.760135
# min    2.000000e+00      0.000000      0.000000        0.000000      0.000000
# 25%    6.813480e+05      0.000000      0.000000        0.000000      0.000000
# 50%    1.043907e+06      3.000000      3.000000        0.000000      3.000000
# 75%    1.451159e+06      9.000000      6.000000        3.000000      6.000000
# max    2.103039e+06     63.000000     18.000000       38.000000     48.000000
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  33901.000000     33901.000000    33901.000000  33901.000000
# mean       0.998938         3.048022        0.001770      5.087343
# std        2.351764         4.624004        0.072846      5.230697
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      3.000000
# 75%        0.000000         3.000000        0.000000      9.000000
# max       15.000000        39.000000        3.000000     32.000000
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  33901.000000  33901.000000  33901.000000  33901.000000  33901.000000
# mean       4.750450      0.462995      1.017433      2.269461      0.315802
# std        7.216228      1.055186      2.342532      4.310752      1.363462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      0.000000      0.000000      0.000000      0.000000
# 75%        6.000000      0.000000      0.000000      3.000000      0.000000
# max       54.000000      6.000000     18.000000     54.000000     15.000000
#
#          Blockchain
# count  33901.000000
# mean       0.986844
# std        1.950585
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000

# %% [markdown]
# The original user profile feature vector is not normalized, which may cause issues when we perform clustering and Principal component analysis (PCA), therefor we standardize the data.

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
# Instantiating a StandardScaler object
scaler = StandardScaler()

# Standardizing the selected features (feature_names) in the user_profile_df DataFrame
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df[feature_names])

# Printing the mean and standard deviation of the standardized features
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(), user_profile_df[feature_names].std()))
# Out:
# mean Database          -3.353495e-17
# Python            -5.700942e-17
# CloudComputing    -3.521170e-17
# DataAnalysis      -7.671120e-17
# Containers         3.353495e-18
# MachineLearning    3.688845e-17
# ComputerVision    -1.509073e-17
# DataScience       -1.676748e-17
# BigData            6.706990e-17
# Chatbot           -6.874665e-17
# R                  4.233788e-17
# BackendDev         1.383317e-17
# FrontendDev        5.051202e-17
# Blockchain        -5.281755e-17
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  3.390100e+04  3.390100e+04    3.390100e+04  3.390100e+04
# mean   1.064064e+06 -3.353495e-17 -5.700942e-17   -3.521170e-17 -7.671120e-17
# std    4.972578e+05  1.000015e+00  1.000015e+00    1.000015e+00  1.000015e+00
# min    2.000000e+00 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 25%    6.813480e+05 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 50%    1.043907e+06 -3.308757e-01 -1.168130e-01   -6.005256e-01 -1.312380e-01
# 75%    1.451159e+06  4.573712e-01  5.928781e-01    1.803581e-01  4.990056e-01
# max    2.103039e+06  7.551593e+00  3.431642e+00    9.290667e+00  9.322416e+00
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  3.390100e+04     3.390100e+04    3.390100e+04  3.390100e+04
# mean   3.353495e-18     3.688845e-17   -1.509073e-17 -1.676748e-17
# std    1.000015e+00     1.000015e+00    1.000015e+00  1.000015e+00
# min   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 25%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 50%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -3.990622e-01
# 75%   -4.247674e-01    -1.038556e-02   -2.429612e-02  7.480294e-01
# max    5.953517e+00     7.775190e+00    4.115884e+01  5.145214e+00
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04
# mean   6.706990e-17 -6.874665e-17  4.233788e-17  1.383317e-17  5.051202e-17
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 25%   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 50%   -3.811535e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 75%    1.731609e-01 -4.387873e-01 -4.343370e-01  1.694715e-01 -2.316212e-01
# max    6.824934e+00  5.247500e+00  7.249771e+00  1.200053e+01  1.076995e+01
#
#          Blockchain
# count  3.390100e+04
# mean  -5.281755e-17
# std    1.000015e+00
# min   -5.059295e-01
# 25%   -5.059295e-01
# 50%   -5.059295e-01
# 75%    5.194189e-01
# max    5.646161e+00

# %% [markdown]
# The normalized user profile features are:

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
features
# Out:
#        Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0      6.106474  2.485388        0.961242      8.272010    0.850889
# 1      4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2      2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4      0.063248 -0.826504       -0.600526      0.078843   -0.424767
# ...         ...       ...             ...           ...         ...
# 33896 -0.330876 -0.116813        0.180358      0.499006   -0.424767
# 33897 -0.724999 -0.826504       -0.079936     -0.761482   -0.424767
# 33898 -0.330876  0.592878        0.961242     -0.761482   -0.424767
# 33899 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
# 33900 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
#
#        MachineLearning  ComputerVision  DataScience   BigData   Chatbot  \
# 0             6.477594       -0.024296     4.571668  5.023412  1.456642
# 1             2.368540       -0.024296     2.851031  2.667576 -0.438787
# 2             5.828796       -0.024296     3.233395  1.281790  1.456642
# 3            -0.659184       -0.024296    -0.972608 -0.381153 -0.438787
# 4            -0.659184       -0.024296    -0.972608  0.173161 -0.438787
# ...                ...             ...          ...       ...       ...
# 33896        -0.659184       -0.024296     0.174484 -0.658311 -0.438787
# 33897        -0.659184       -0.024296    -0.972608 -0.658311 -0.438787
# 33898         2.368540       -0.024296     0.748029 -0.658311 -0.438787
# 33899        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
# 33900        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
#
#               R  BackendDev  FrontendDev  Blockchain
# 0      7.249771    7.360899     6.369323    2.570116
# 1      2.127032    0.865416    -0.231621    0.519419
# 2      5.542191    5.505047     2.702132    2.570116
# 3     -0.434337   -0.526473    -0.231621   -0.505930
# 4      0.419453   -0.526473    -0.231621   -0.505930
# ...         ...         ...          ...         ...
# 33896  2.127032    0.865416    -0.231621    1.032093
# 33897 -0.434337   -0.526473    -0.231621   -0.505930
# 33898  0.846348   -0.526473    -0.231621   -0.505930
# 33899 -0.434337   -0.526473    -0.231621   -0.505930
# 33900 -0.434337   -0.526473    -0.231621   -0.505930
#
# [33901 rows x 14 columns]

# %% [markdown]
# we can also save the user ids for later recommendation tasks:

# %%
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
user_ids
# Out:
#           user
# 0            2
# 1            4
# 2            5
# 3            7
# 4            8
# ...        ...
# 33896  2102054
# 33897  2102356
# 33898  2102680
# 33899  2102983
# 33900  2103039
#
# [33901 rows x 1 columns]

# %% [markdown]
# ### TASK: Perform K-means clustering algorithm on the user profile feature vectors

# %% [markdown]
# With the user profile dataset ready, you need to use the `KMeans` class provided by scikit-learn library to perform clustering on the user profile feature vectors.

# %% [markdown]
# For `KMeans` algorithm, one important hyperparameter is the number of clusters `n_cluster`, and a good way to find the optimized `n_cluster` is using to grid search a list of candidates and find the one with the best or optimized clustering evaluation metrics such as minimal `sum of squared distance`:

# %% [markdown]
# _TODO: grid search the optimized n_cluster for KMeans() model_

# %%
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

# %%
# WRITE YOUR CODE HERE

# Find an optimized number of neighors k from a candidate list such as list_k = list(range(1, 30))
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

distorsions = []
for k in range(1, 30):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(features)
    distorsions.append(kmeans.inertia_)

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(range(1, 30), distorsions,marker='o')
plt.grid(True)
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Sum of Squared Distances')
# Out:
# Text(0, 0.5, 'Sum of Squared Distances')

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create a list that will hold the the sum of square distances for each fitted model. For each k in `n_clusters` make a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)` ans append `model.inertia_` to the list. Plot square distances against the k values.
#
# </details>

# %% [markdown]
# If you plot the grid search process, you may get a elbow plot like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/clusters_elbow.png)

# %% [markdown]
# From the elbow plot, you should visualy identify the point where the metric starting to be flatten, which indicates the optimized number of clusters.

# %% [markdown]
# Once you have identified the best number of clusters, you can apply `KMeans()` again to generate cluster label for all users.

# %%
cluster_labels = kmeans.labels_
cluster_labels.shape
# Out:
# (33901,)

# %% [markdown]
# _TODO: Apply KMeans() on the features with optimized n_cluster parameter after model fitting, you can find output cluster labels in `model.labels_` attribute_

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create  a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)`. Save the labels by accessing `model.labels`.
#
# </details>

# %% [markdown]
# The cluster labels you generated is a list of integers indicating cluster indices. You may use the following utility method to combine the cluster labels and user ids to a dataframe, so that you know which cluster a user belongs:

# %%
def combine_cluster_labels(user_ids, labels):
    # Convert labels to a DataFrame
    labels_df = pd.DataFrame(labels)    
    # Merge user_ids DataFrame with labels DataFrame based on index
    cluster_df = pd.merge(user_ids, labels_df, left_index=True, right_index=True)
    # Rename columns to 'user' and 'cluster'
    cluster_df.columns = ['user', 'cluster']
    return cluster_df

# %%
# Call the utility method to combine user IDs and cluster labels into a DataFrame
cluster_df = combine_cluster_labels(user_ids, cluster_labels)

# Display the resulting DataFrame
print(cluster_df)
# Out:
#           user  cluster
# 0            2       26
# 1            4       22
# 2            5       14
# 3            7        0
# 4            8        6
# ...        ...      ...
# 33896  2102054       10
# 33897  2102356        0
# 33898  2102680       27
# 33899  2102983        0
# 33900  2103039        0
#
# [33901 rows x 2 columns]

# %% [markdown]
# Now, each user finds its own cluster or we can say we have created many clusters of learning communities. Learners within each community share very similar learning interests.

# %% [markdown]
# ### TASK: Apply PCA on user profile feature vectors to reduce dimensions

# %% [markdown]
# In the previous step, we applied `KMeans` on the original user profile feature vectors which have 14 original features (the course genres).

# %%
# Extracting features from the user_profile_df DataFrame, excluding the 'user' column
features = user_profile_df.loc[:, user_profile_df.columns != 'user']

# Extracting user IDs from the user_profile_df DataFrame
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']

# Creating a list of feature names by excluding the 'user' column name
feature_names = list(user_profile_df.columns[1:])

# %%
print(f"There are {len(feature_names)} features for each user profile.")
# Out:
# There are 14 features for each user profile.

# %% [markdown]
# If we plot a covariance matrix of the user profile feature vectors with 14 features, we can observe that some features are actually correlated:

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = features.cov()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


plt.show()

# %% [markdown]
# For example, the feature `MachineLearning` and the feature `DataScience` are correlated. Such covariances among features may indicate that we can apply PCA to find its main components (eigenvectors with max eigenvalues on the covariance matrix).
#
# If we only keep the independent main components, then we can reduce the dimensions of our user profile feature vectors.

# %% [markdown]
# Now let's apply the `PCA()` provided by  `scikit-learn` to find the main components in user profile feature vectors and see if we can reduce its dimensions by only keeping the main components.

# %% [markdown]
# Note that when calling the  `PCA()` class, there is also an import argument called `n_components` which indicates how many components you want to keep in the PCA result. One way to find an optimized `n_components` is to do a grid search on a list of argument candidates (such as `range(1, 15)`) and calculate the ratio of the accumulated variance for each candidate.
#
# If the accumulated variances ratio of a candidate `n_components` is larger than a threshold, e.g., 90%, then we can say the transformed `n_components` could explain about 90% of variances of the original data variance and can be considered as an optimized components size.

# %% [markdown]
# _TODO: Find the optimized `n_components` for PCA_

# %%
from sklearn.decomposition import PCA

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
accVarRatio = []

for n_components in range(1, 15):
    pca = PCA(n_components=n_components)
    pca.fit(features)

    print(pca.explained_variance_ratio_.sum())
    print(pca.singular_values_)

    accVarRatio.append(pca.explained_variance_ratio_.sum())
# Out:
# 0.28756843387699677
# [369.43741645]
# 0.4630925644817452
# [369.43741645 288.6281513 ]
# 0.5761339643675618
# [369.43741645 288.6281513  231.62692194]
# 0.6487465627832345
# [369.43741645 288.6281513  231.62692194 185.64200975]
# 0.7194878762997213
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477]
# 0.7882103410314039
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592]
# 0.8429558465572832
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997]
# 0.8944445500368899
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282]
# 0.9272695591307681
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107]
# 0.9544658170614703
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819]
# 0.9733572103164774
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667]
# 0.9870310843021106
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667  80.55936958]
# 0.9979163166617693
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667  80.55936958  71.87686464]
# 1.0
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667  80.55936958  71.87686464  31.44750044]

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * For each `n_components` from 1 to 14 you can call `PCA=PCA(n_components=component)`, then you can simply fit it by callsing `pca.fit_transform(features)` where `features = user_profile_df.loc[:, user_profile_df.columns != 'user']`.
# * Then you can find `accumulated_variance_ratios` by applying `sum()` to `pca.explained_variance_ratio_`.
# * Then find the smallest n_components value for which `accumulated_variance_ratios >= 0.9` and return it.
# </details>

# %%
plot_df = pd.DataFrame({'n_component': range(1, 15), 'accumulated variance ratio': accVarRatio})
sns.barplot(x='n_component', y='accumulated variance ratio', data=plot_df)
# Out:
# <Axes: xlabel='n_component', ylabel='accumulated variance ratio'>

# %% [markdown]
# If you visualize your hyperparameter searching process, you may get a trend line like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca.png)

# %% [markdown]
# Once you found the optimized `n_component` argument value, you can apply PCA on the user profile feature vectors and reduce the  14 features into  `n_component` features.

# %% [markdown]
# _TODO: Perform PCA to transform original user profile features_

# %%
for i in range(len(accVarRatio)):
    if accVarRatio[i] > 0.9:
        print(i)
# Out:
# 8
# 9
# 10
# 11
# 12
# 13

# %%
# We select n_component = 8, due to the minimal ratio > 0.9
pca = PCA(n_components=9)
pca.fit(features)
transformed_features = pca.transform(features)
print(transformed_features)
# Out:
# [[17.77249439  0.20068141  1.73060927 ...  0.681042    2.31261304
#    0.86827151]
#  [ 7.14519863 -2.84748121  2.3586356  ...  0.54976933  0.46903346
#    0.03340487]
#  [11.36326985  1.8736192  -1.52207738 ...  1.67758234  2.9376687
#    2.09763858]
#  ...
#  [ 0.62594328 -0.54716673 -1.69282423 ... -0.05509971  0.58209105
#    1.70319253]
#  [-2.03683187 -0.15353383  0.16285226 ...  0.07249638  0.11374975
#    0.62289958]
#  [-2.03683187 -0.15353383  0.16285226 ...  0.07249638  0.11374975
#    0.62289958]]

# %%
new_df = pd.DataFrame(transformed_features)
new_df
# Out:
#                0         1         2         3         4         5         6  \
# 0      17.772494  0.200681  1.730609  2.567359 -3.825814 -2.707154  0.681042
# 1       7.145199 -2.847481  2.358636 -0.576654  0.398803  0.134533  0.549769
# 2      11.363270  1.873619 -1.522077  1.076144 -1.711688 -0.883212  1.677582
# 3      -1.834033 -0.277462  0.564905  0.053470 -0.064440 -0.165757  0.030956
# 4      -1.049125 -0.684767  1.072765  0.006371 -0.005695 -0.118686  0.118559
# ...          ...       ...       ...       ...       ...       ...       ...
# 33896   0.633824  0.108815 -0.388871 -0.122665 -0.098364 -0.358333  1.752049
# 33897  -2.095339  0.135058  0.244727 -0.088185  0.025081 -0.183641  0.046413
# 33898   0.625943 -0.547167 -1.692824 -0.630589  0.166632 -0.676244 -0.055100
# 33899  -2.036832 -0.153534  0.162852  0.082651 -0.126419 -0.255109  0.072496
# 33900  -2.036832 -0.153534  0.162852  0.082651 -0.126419 -0.255109  0.072496
#
#               7         8
# 0      2.312613  0.868272
# 1      0.469033  0.033405
# 2      2.937669  2.097639
# 3      0.039519  0.210887
# 4      0.559292  0.186379
# ...         ...       ...
# 33896  1.486542 -0.523600
# 33897  0.191709  0.260437
# 33898  0.582091  1.703193
# 33899  0.113750  0.622900
# 33900  0.113750  0.622900
#
# [33901 rows x 9 columns]

# %%
new_df.insert(0, "user", user_ids, True)

# %%
new_df
# Out:
#           user          0         1         2         3         4         5  \
# 0            2  17.772494  0.200681  1.730609  2.567359 -3.825814 -2.707154
# 1            4   7.145199 -2.847481  2.358636 -0.576654  0.398803  0.134533
# 2            5  11.363270  1.873619 -1.522077  1.076144 -1.711688 -0.883212
# 3            7  -1.834033 -0.277462  0.564905  0.053470 -0.064440 -0.165757
# 4            8  -1.049125 -0.684767  1.072765  0.006371 -0.005695 -0.118686
# ...        ...        ...       ...       ...       ...       ...       ...
# 33896  2102054   0.633824  0.108815 -0.388871 -0.122665 -0.098364 -0.358333
# 33897  2102356  -2.095339  0.135058  0.244727 -0.088185  0.025081 -0.183641
# 33898  2102680   0.625943 -0.547167 -1.692824 -0.630589  0.166632 -0.676244
# 33899  2102983  -2.036832 -0.153534  0.162852  0.082651 -0.126419 -0.255109
# 33900  2103039  -2.036832 -0.153534  0.162852  0.082651 -0.126419 -0.255109
#
#               6         7         8
# 0      0.681042  2.312613  0.868272
# 1      0.549769  0.469033  0.033405
# 2      1.677582  2.937669  2.097639
# 3      0.030956  0.039519  0.210887
# 4      0.118559  0.559292  0.186379
# ...         ...       ...       ...
# 33896  1.752049  1.486542 -0.523600
# 33897  0.046413  0.191709  0.260437
# 33898 -0.055100  0.582091  1.703193
# 33899  0.072496  0.113750  0.622900
# 33900  0.072496  0.113750  0.622900
#
# [33901 rows x 10 columns]

# %%
new_df. columns = ['user'] + [f'PC{i}' for i in range(9)]
new_df
# Out:
#           user        PC0       PC1       PC2       PC3       PC4       PC5  \
# 0            2  17.772494  0.200681  1.730609  2.567359 -3.825814 -2.707154
# 1            4   7.145199 -2.847481  2.358636 -0.576654  0.398803  0.134533
# 2            5  11.363270  1.873619 -1.522077  1.076144 -1.711688 -0.883212
# 3            7  -1.834033 -0.277462  0.564905  0.053470 -0.064440 -0.165757
# 4            8  -1.049125 -0.684767  1.072765  0.006371 -0.005695 -0.118686
# ...        ...        ...       ...       ...       ...       ...       ...
# 33896  2102054   0.633824  0.108815 -0.388871 -0.122665 -0.098364 -0.358333
# 33897  2102356  -2.095339  0.135058  0.244727 -0.088185  0.025081 -0.183641
# 33898  2102680   0.625943 -0.547167 -1.692824 -0.630589  0.166632 -0.676244
# 33899  2102983  -2.036832 -0.153534  0.162852  0.082651 -0.126419 -0.255109
# 33900  2103039  -2.036832 -0.153534  0.162852  0.082651 -0.126419 -0.255109
#
#             PC6       PC7       PC8
# 0      0.681042  2.312613  0.868272
# 1      0.549769  0.469033  0.033405
# 2      1.677582  2.937669  2.097639
# 3      0.030956  0.039519  0.210887
# 4      0.118559  0.559292  0.186379
# ...         ...       ...       ...
# 33896  1.752049  1.486542 -0.523600
# 33897  0.046413  0.191709  0.260437
# 33898 -0.055100  0.582091  1.703193
# 33899  0.072496  0.113750  0.622900
# 33900  0.072496  0.113750  0.622900
#
# [33901 rows x 10 columns]

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * Call PCA class as `pca = PCA(n_components=n_components)`
# * Fit PCA model using predefined `features` variable as only parameter
# * Get the components by calling `pca.fit_transform(features)`
# * Create a `pd.DataFrame(data=components)` and use `pd.merge` to merge it with `user_ids` don't forget to specify `left_index=True, right_index=True` in `merge` function parameters.
#
# </details>

# %% [markdown]
# Your PCA transformed dataframe may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca_res.png)

# %% [markdown]
# ### TASK: Perform k-means clustering on the PCA transformed feature vectors

# %% [markdown]
# Now, you have the PCA  components of the original profile vectors. You can perform k-means on them again:

# %% [markdown]
# _TODO: Perform K-means on the PCA transformed features_

# %%
## WRITE YOUR CODE HERE

## - Apply KMeans() on the PCA features
## - Obtain the cluster label lists from model.labels_ attribute
## - Assign each user a cluster label by combining user ids and cluster labels
from sklearn.cluster import KMeans

# Define the number of clusters
n_clusters = 5  # or any other desired number of clusters

# Apply KMeans on the PCA transformed features
kmeans_pca = KMeans(n_clusters=n_clusters, random_state=rs)
kmeans_pca.fit(transformed_features)

# Obtain the cluster labels
pca_cluster_labels = kmeans_pca.labels_

# Combine user IDs and cluster labels
pca_cluster_df = combine_cluster_labels(user_ids, pca_cluster_labels)

# Display the resulting dataframe
print(pca_cluster_df)
# Out:
#           user  cluster
# 0            2        0
# 1            4        0
# 2            5        0
# 3            7        2
# 4            8        2
# ...        ...      ...
# 33896  2102054        1
# 33897  2102356        2
# 33898  2102680        1
# 33899  2102983        2
# 33900  2103039        2
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results should have the same format as the k-means on the original dataset:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Great, now all users find their learning interest groups, either based on their original or the PCA transformed user profile features.

# %% [markdown]
# When a user is in a group or a community, it is very likely that the user will be interested in the courses enrolled by other members within the same group.

# %% [markdown]
# ### TASK: Generate course recommendations based on the popular courses in the same cluster

# %% [markdown]
# The Intuition of clustering-based course recommendation is very simple and can be illustrated via the following example:

# %% [markdown]
# Suppose a user has joined a machine learning group (via clustering algorithm). In the group, he/she finds that the top-3 courses enrolled by all other group members are `Machine Learning for Everyone`, `Machine Learning with Python`, `Machine Learning with Scikit-learn`. Since the user has already completed the `Machine Learning for Everyone` earlier, he/she decides to trust the group members' choices and enroll in other two unselected courses `Machine Learning with Python` and `Machine Learning with Scikit-learn`.

# %% [markdown]
# In summary, the clustering-based recommender system first groups all users based on their profiles, and maintains a popular courses list for each group.
#
# For any group member who needs course recommendations, the algorithm recommends the unselected courses from the popular course lists.

# %% [markdown]
# Next, suppose we have a set of test users, and we want to recommend new courses to them using a clustering-based recommender system:

# %%
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"

# Reading the test user data CSV file into a pandas DataFrame
# Selecting only the 'user' and 'item' columns using indexing
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]

# Displaying the first few rows of the DataFrame to inspect its contents
test_users_df.head()
# Out:
#       user      item
# 0  1502801  RP0105EN
# 1  1609720  CNSC02EN
# 2  1347188  CO0301EN
# 3   755067  ML0103EN
# 4   538595  BD0115EN

# %% [markdown]
# The test users dataset has only two columns, the user id and the enrolled course id.

# %% [markdown]
# For each user, let's find its cluster label using the k-means results you have performed in previous steps, assuming it is named `cluster_df`.

# %% [markdown]
# You can assign the cluster label to all test users via merging the clustering labels (`cluster_df`:):

# %%
test_users_labelled = pd.merge(test_users_df, cluster_df, left_on='user', right_on='user')
test_users_labelled
# Out:
#          user      item  cluster
# 0     1502801  RP0105EN       13
# 1     1502801  BD0131EN       13
# 2     1502801  BD0212EN       13
# 3     1502801  BD0115EN       13
# 4     1502801  BD0211EN       13
# ...       ...       ...      ...
# 9397   630511  BD0121EN        6
# 9398   630511  SC0101EN        6
# 9399   630511  BD0111EN        6
# 9400   630511  BD0115EN        6
# 9401   630511  PY0101EN        6
#
# [9402 rows x 3 columns]

# %% [markdown]
# The merged the test dataset may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/test_users_label.png)

# %% [markdown]
# From the above dataframe, we know each user's enrolled courses and its cluster index.

# %% [markdown]
# If we use a `groupby`  and `sum` aggregation, we can get the enrollments count for each course in each group, like the following code snippet:

# %%
# Extracting the 'item' and 'cluster' columns from the test_users_labelled DataFrame
courses_cluster = test_users_labelled[['item', 'cluster']]

# Adding a new column 'count' with a value of 1 for each row in the courses_cluster DataFrame
courses_cluster['count'] = [1] * len(courses_cluster)

# Grouping the DataFrame by 'cluster' and 'item', aggregating the 'count' column with the sum function,
# and resetting the index to make the result more readable
courses_cluster_grouped = courses_cluster.groupby(['cluster','item']).agg(enrollments=('count','sum')).reset_index()
courses_cluster_grouped
# Out:
#       cluster      item  enrollments
# 0           0  AI0111EN            1
# 1           0  BC0101EN           30
# 2           0  BC0201EN           17
# 3           0  BC0202EN            3
# 4           0  BD0101EN           53
# ...       ...       ...          ...
# 1514       28  ST0101EN           11
# 1515       28  SW0201EN            1
# 1516       28    TA0105            2
# 1517       28  TA0105EN            2
# 1518       28  WA0101EN            9
#
# [1519 rows x 3 columns]

# %% [markdown]
# _TODO: For each test user, try to recommend any unseen courses based on the popular courses in his/her cluster. You may use an enrollment count threshold (such as larger than 10) to determine if it is a popular course in the cluster_

# %%
## WRITE YOUR CODE HERE

## - For each user, first finds its cluster label

    ## - First get all courses belonging to the same cluster and figure out what are the popular ones (such as course enrollments beyond a threshold like 100)
    
    ## - Get the user's current enrolled courses
    
    ## - Check if there are any courses on the popular course list which are new/unseen to the user. 
    
    ## If yes, make those unseen and popular courses as recommendation results for the user

# Define a function to generate course recommendations for each test user
def generate_course_recommendations(test_users_labelled, courses_cluster_grouped, enrollment_threshold=10):
    # Initialize an empty dictionary to store recommendations for each user
    recommendations = {}

    # Iterate through each test user
    for user_id in test_users_labelled['user'].unique():
        # Filter the DataFrame to get information about the current user
        user_subset = test_users_labelled[test_users_labelled['user'] == user_id]
        
        # Get the enrolled courses of the current user
        enrolled_courses = set(user_subset['item'])
        
        # Get the cluster label of the current user (assuming all entries have the same cluster label for a user)
        cluster_id = user_subset['cluster'].iloc[0]
        
        # Get all courses belonging to the same cluster as the current user
        cluster_courses = set(courses_cluster_grouped[courses_cluster_grouped['cluster'] == cluster_id]['item'])
        
        # Find new/unseen courses to the user by taking a set difference
        unseen_courses = cluster_courses.difference(enrolled_courses)
        
        # Filter popular courses among unseen courses based on enrollment threshold
        popular_unseen_courses = set(courses_cluster_grouped[
            (courses_cluster_grouped['cluster'] == cluster_id) & 
            (courses_cluster_grouped['item'].isin(unseen_courses)) & 
            (courses_cluster_grouped['enrollments'] >= enrollment_threshold)
        ]['item'])
        
        # Add the recommended courses to the dictionary
        recommendations[user_id] = popular_unseen_courses
    
    return recommendations

# Generate course recommendations for each test user
recommendations = generate_course_recommendations(test_users_labelled, courses_cluster_grouped)

# Display recommendations for the first few users
for user_id, recommended_courses in recommendations.items():
    print(f"User {user_id}: Recommended courses - {recommended_courses}")
# Out:
# User 1502801: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0121EN', 'BD0143EN'}
# User 1609720: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0115EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 1347188: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CC0101EN', 'CO0101EN', 'CL0101EN', 'CC0250EN'}
# User 755067: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 538595: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0143EN'}
# User 1773079: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'BC0101EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 603361: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'CC0101EN', 'CO0301EN', 'BC0101EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1122903: Recommended courses - {'BD0123EN', 'DS0321EN', 'PA0101EN', 'CC0201EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'RP0105EN', 'ML0101EN', 'DE0205EN', 'DS0105EN', 'ST0101EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'ML0120EN', 'DS0101EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 714414: Recommended courses - {'BD0101EN', 'CC0101EN', 'BD0111EN', 'CO0101EN'}
# User 1688159: Recommended courses - set()
# User 703905: Recommended courses - set()
# User 881847: Recommended courses - {'BD0101EN', 'ML0101ENv3', 'DS0101EN', 'DS0103EN'}
# User 1784245: Recommended courses - set()
# User 1443131: Recommended courses - {'PY0101EN', 'DV0101EN', 'DS0101EN', 'DA0101EN', 'DS0105EN', 'ST0101EN', 'DS0103EN', 'ML0101EN'}
# User 1773434: Recommended courses - {'CO0301EN', 'CO0401EN', 'CL0101EN'}
# User 489692: Recommended courses - set()
# User 430274: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0115EN', 'ST0101EN', 'BD0101EN', 'DS0103EN'}
# User 1394499: Recommended courses - set()
# User 1221910: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0101ENv3', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'CC0101EN'}
# User 1636610: Recommended courses - {'BD0111EN', 'DS0105EN', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'DS0103EN'}
# User 1504635: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'CO0201EN', 'CO0301EN', 'BC0101EN', 'CL0101EN', 'CC0103EN'}
# User 616284: Recommended courses - set()
# User 462755: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'DAI101EN', 'CO0201EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 902138: Recommended courses - {'BD0212EN', 'BD0143EN', 'BD0121EN', 'DS0101EN'}
# User 1102170: Recommended courses - set()
# User 510780: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'DA0101EN', 'CC0101EN', 'CB0103EN'}
# User 220851: Recommended courses - {'ST0101EN', 'BD0101EN', 'RP0101EN', 'BD0111EN'}
# User 952742: Recommended courses - set()
# User 704521: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'RP0105EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'DE0205EN', 'BD0101EN', 'CO0301EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'SC0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN'}
# User 517197: Recommended courses - {'ML0115EN', 'ML0101ENv3'}
# User 1806207: Recommended courses - {'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 1648099: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'CL0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'CB0103EN'}
# User 108541: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1642918: Recommended courses - {'BD0101EN', 'DS0105EN', 'BD0111EN', 'DS0103EN'}
# User 601371: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'DV0151EN', 'BD0101EN', 'ML0151EN'}
# User 1199884: Recommended courses - {'DS0105EN', 'BD0111EN'}
# User 531408: Recommended courses - {'PY0101EN', 'DA0101EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 708518: Recommended courses - set()
# User 1351020: Recommended courses - {'BD0101EN', 'DS0101EN', 'ML0120ENv2'}
# User 472908: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 482875: Recommended courses - {'ML0101EN', 'DS0103EN', 'DS0105EN', 'BD0211EN'}
# User 1541383: Recommended courses - {'DS0101EN', 'ML0122ENv1', 'DS0105EN', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 877026: Recommended courses - {'PY0101EN', 'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'RP0101EN'}
# User 755044: Recommended courses - {'PY0101EN', 'DV0101EN', 'DS0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0115EN', 'ST0101EN', 'DS0103EN', 'ML0101EN'}
# User 913275: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0101EN', 'BD0121EN', 'BD0143EN'}
# User 1275452: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 985429: Recommended courses - {'ML0115EN', 'ML0101ENv3', 'BD0115EN', 'ST0101EN', 'ML0101EN'}
# User 1237626: Recommended courses - {'ML0101ENv3', 'BD0111EN'}
# User 577001: Recommended courses - {'PY0101EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'DE0205EN', 'ST0101EN', 'CO0301EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'CB0103EN'}
# User 981848: Recommended courses - {'ML0151EN'}
# User 1751931: Recommended courses - {'BD0111EN', 'DS0101EN', 'DV0101EN', 'DS0105EN', 'BD0101EN', 'DS0103EN'}
# User 1378699: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 705065: Recommended courses - {'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'BD0101EN', 'CC0101EN', 'CO0301EN', 'DS0103EN', 'CO0101EN'}
# User 1452505: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'CC0101EN', 'BC0101EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 762860: Recommended courses - {'ML0115EN', 'BD0101EN', 'ML0101ENv3'}
# User 1571271: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'BD0101EN', 'DS0103EN'}
# User 767649: Recommended courses - set()
# User 1194679: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0101EN', 'BD0121EN', 'BD0143EN'}
# User 1882084: Recommended courses - {'ML0115EN', 'DA0101EN', 'ML0101ENv3', 'BD0115EN', 'ML0101EN'}
# User 1506139: Recommended courses - {'RP0101EN', 'WA0101EN', 'BD0111EN'}
# User 569052: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1316258: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'BD0101EN', 'DS0103EN'}
# User 1016747: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0212EN', 'BD0121EN', 'BD0143EN'}
# User 696345: Recommended courses - {'ML0115EN', 'RP0101EN', 'PY0101EN', 'ST0101EN'}
# User 494226: Recommended courses - {'PY0101EN', 'DV0101EN', 'DS0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0115EN', 'ST0101EN', 'DS0103EN'}
# User 699465: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'DB0101EN'}
# User 886106: Recommended courses - {'ML0115EN', 'ML0101ENv3', 'CO0201EN', 'CO0301EN', 'CO0101EN'}
# User 740210: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0121EN'}
# User 690872: Recommended courses - {'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 705746: Recommended courses - {'BD0131EN', 'DS0321EN', 'DV0151EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'ML0151EN', 'RP0101EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'SC0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN'}
# User 759038: Recommended courses - {'DV0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0101EN', 'DS0103EN', 'ML0101EN'}
# User 1212187: Recommended courses - {'ML0122ENv1', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'DB0101EN'}
# User 1715864: Recommended courses - set()
# User 738131: Recommended courses - {'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 793367: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0101EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 1271375: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'ML0122ENv1', 'ST0101EN', 'BD0101EN', 'WA0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1405594: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'CO0201EN', 'CO0301EN', 'CL0101EN', 'CC0250EN'}
# User 266643: Recommended courses - {'ML0101ENv3', 'CC0201EN', 'CO0301EN', 'BC0101EN', 'CC0103EN', 'CC0250EN'}
# User 1194262: Recommended courses - {'CC0201EN', 'CC0101EN', 'CC0103EN', 'BC0101EN'}
# User 1474331: Recommended courses - {'CC0101EN', 'WA0101EN'}
# User 1538828: Recommended courses - {'DS0321EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 669512: Recommended courses - {'DV0101EN', 'DA0101EN', 'ML0101ENv3', 'ST0101EN', 'DS0301EN', 'ML0120ENv2', 'DB0101EN'}
# User 1287782: Recommended courses - {'CC0201EN', 'CC0101EN', 'BC0101EN', 'CL0101EN', 'CC0103EN'}
# User 1006163: Recommended courses - {'ML0115EN', 'DS0105EN', 'DV0101EN', 'DS0103EN'}
# User 2021696: Recommended courses - {'DS0101EN', 'ML0120ENv2', 'ML0122ENv1', 'DS0105EN', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DS0103EN', 'DB0101EN'}
# User 970895: Recommended courses - {'PY0101EN', 'DS0105EN', 'DV0101EN', 'DS0103EN'}
# User 1596323: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CO0201EN', 'BC0101EN', 'CL0101EN', 'CC0103EN'}
# User 979847: Recommended courses - {'ML0115EN', 'ML0122ENv1', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'ML0120ENv2', 'DB0101EN'}
# User 738953: Recommended courses - {'PY0101EN', 'DV0101EN', 'DA0101EN', 'ML0101ENv3', 'BD0101EN', 'CO0101EN'}
# User 1095855: Recommended courses - {'CC0101EN', 'DS0103EN', 'DS0101EN', 'CO0101EN'}
# User 998607: Recommended courses - {'PY0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 1521903: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 539916: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0121EN', 'BD0115EN'}
# User 1404598: Recommended courses - {'BD0101EN', 'RP0101EN', 'DS0301EN'}
# User 1563448: Recommended courses - {'DS0301EN'}
# User 887336: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN'}
# User 1206954: Recommended courses - {'DV0101EN', 'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'BD0115EN', 'ML0101EN'}
# User 1783867: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'BD0211EN', 'CO0201EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN'}
# User 1224751: Recommended courses - {'CC0201EN', 'CO0401EN', 'BC0101EN'}
# User 1444838: Recommended courses - {'DS0101EN', 'ML0101ENv3', 'CO0201EN', 'CC0201EN', 'BC0101EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 560247: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 2004142: Recommended courses - {'PY0101EN', 'BD0111EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'RP0101EN'}
# User 1078030: Recommended courses - {'DS0101EN', 'DS0105EN', 'PA0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DS0103EN', 'DB0101EN'}
# User 621543: Recommended courses - {'PY0101EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 684186: Recommended courses - {'BD0212EN', 'PY0101EN', 'BD0121EN', 'SC0101EN'}
# User 152320: Recommended courses - {'PY0101EN', 'DV0101EN', 'DS0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0115EN', 'ST0101EN', 'BD0101EN', 'DS0103EN'}
# User 578677: Recommended courses - {'ST0101EN', 'CC0101EN', 'ML0101ENv3', 'DS0321EN'}
# User 701650: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0115EN', 'ST0101EN', 'DS0103EN', 'RP0101EN'}
# User 1061706: Recommended courses - set()
# User 399457: Recommended courses - {'BD0111EN', 'DS0101EN', 'DV0101EN', 'DA0101EN', 'ML0101ENv3', 'BD0101EN', 'CC0101EN', 'DS0103EN'}
# User 187819: Recommended courses - set()
# User 2022708: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 1355756: Recommended courses - {'RP0101EN', 'CC0101EN', 'WA0101EN'}
# User 1215047: Recommended courses - {'PY0101EN', 'BD0123EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1313360: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0212EN', 'BD0131EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 952216: Recommended courses - set()
# User 1458003: Recommended courses - {'RP0101EN', 'BD0111EN', 'DS0101EN', 'DS0103EN'}
# User 627837: Recommended courses - {'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'DS0103EN', 'DB0101EN'}
# User 1736248: Recommended courses - {'ML0115EN', 'ML0122ENv1', 'ST0101EN', 'DS0301EN', 'ML0120ENv2', 'DS0103EN'}
# User 1208551: Recommended courses - {'BD0101EN', 'CC0101EN', 'BD0111EN', 'BD0211EN'}
# User 1391909: Recommended courses - {'BD0101EN', 'BD0111EN', 'DS0101EN'}
# User 1571241: Recommended courses - {'BD0111EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DB0101EN'}
# User 1730632: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0211EN', 'CO0201EN', 'BD0101EN', 'CO0301EN', 'CL0101EN', 'BC0101EN', 'CO0101EN'}
# User 1258208: Recommended courses - set()
# User 753875: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0105EN', 'ML0101ENv3', 'DS0103EN'}
# User 931547: Recommended courses - set()
# User 558382: Recommended courses - {'PY0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN', 'BC0101EN'}
# User 1559681: Recommended courses - {'BD0111EN', 'ML0101ENv3', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN'}
# User 1831769: Recommended courses - {'CC0150EN'}
# User 681552: Recommended courses - {'DV0101EN', 'BD0141EN', 'BD0131EN', 'DS0105EN', 'BD0211EN', 'RP0101EN'}
# User 461049: Recommended courses - set()
# User 1457700: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'WA0101EN', 'CL0101EN', 'CC0103EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'CB0103EN'}
# User 1884765: Recommended courses - set()
# User 1284176: Recommended courses - {'CC0201EN', 'CO0401EN', 'BC0101EN'}
# User 1230771: Recommended courses - {'CC0201EN', 'CC0101EN', 'CC0103EN', 'BC0101EN'}
# User 1273446: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0115EN', 'BD0101EN', 'BD0121EN', 'BD0143EN'}
# User 1104351: Recommended courses - set()
# User 1073082: Recommended courses - {'BD0212EN', 'BD0143EN', 'BD0121EN', 'DS0101EN'}
# User 1964245: Recommended courses - set()
# User 1345617: Recommended courses - {'ML0115EN', 'DS0105EN', 'ST0101EN', 'DS0103EN', 'DB0101EN'}
# User 1130710: Recommended courses - {'LB0105ENv1', 'LB0103ENv1', 'LB0107ENv1'}
# User 1436224: Recommended courses - {'DS0101EN', 'CC0201EN', 'CC0101EN', 'CO0301EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1916547: Recommended courses - {'ML0122ENv1', 'PA0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DB0101EN'}
# User 968795: Recommended courses - {'BD0111EN', 'DS0101EN', 'BD0115EN', 'ST0101EN', 'BD0101EN', 'WA0101EN'}
# User 1208537: Recommended courses - {'BD0111EN', 'DS0105EN', 'ST0101EN', 'DS0103EN', 'DB0101EN'}
# User 1788961: Recommended courses - {'BD0111EN', 'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 696942: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0211EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 951530: Recommended courses - {'PY0101EN', 'DS0101EN', 'BC0201EN'}
# User 419414: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'BD0101EN', 'DS0103EN'}
# User 646160: Recommended courses - {'DV0151EN'}
# User 1688652: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'WA0101EN', 'DB0101EN'}
# User 674939: Recommended courses - set()
# User 1032524: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0121EN', 'BD0143EN'}
# User 1135440: Recommended courses - set()
# User 1138499: Recommended courses - set()
# User 1625215: Recommended courses - {'PY0101EN', 'DV0101EN', 'DS0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'DS0103EN'}
# User 1019556: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'ML0151EN', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'BD0141EN', 'DE0205EN', 'DS0105EN', 'ST0101EN', 'WA0101EN', 'DS0301EN', 'CC0103EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1027344: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'CO0301EN', 'WA0101EN', 'CL0101EN', 'CC0103EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1593639: Recommended courses - {'BD0123EN', 'BD0131EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1669680: Recommended courses - set()
# User 1819037: Recommended courses - {'DV0101EN', 'BD0111EN', 'DS0101EN', 'DS0105EN', 'ST0101EN'}
# User 957960: Recommended courses - {'PY0101EN', 'ML0101ENv3', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN'}
# User 1107112: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CC0103EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1014699: Recommended courses - {'BC0101EN', 'CL0101EN'}
# User 2046621: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 485273: Recommended courses - {'PY0101EN', 'BD0123EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'DA0101EN', 'CC0101EN', 'DS0103EN', 'CB0103EN'}
# User 1196134: Recommended courses - set()
# User 1806813: Recommended courses - {'ML0115EN', 'ML0122ENv1', 'ML0101ENv3', 'ST0101EN', 'DS0301EN', 'RP0101EN'}
# User 1573190: Recommended courses - {'PY0101EN', 'DS0101EN', 'DA0101EN', 'DS0105EN', 'PA0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DS0103EN', 'DB0101EN'}
# User 497128: Recommended courses - {'DA0101EN', 'ML0101ENv3', 'DV0101EN'}
# User 1886079: Recommended courses - {'ML0122ENv1', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DB0101EN'}
# User 899349: Recommended courses - set()
# User 750640: Recommended courses - {'DV0101EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'DS0103EN', 'DB0101EN'}
# User 748522: Recommended courses - {'DS0101EN', 'ML0115EN', 'ML0101ENv3', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN'}
# User 296101: Recommended courses - {'BD0141EN', 'BD0143EN', 'BD0212EN', 'SC0101EN'}
# User 886688: Recommended courses - {'DS0101EN', 'ML0120ENv2', 'ML0122ENv1', 'DS0105EN', 'ML0101ENv3', 'PA0101EN', 'BD0101EN', 'DS0301EN', 'DS0103EN', 'DB0101EN'}
# User 948812: Recommended courses - {'PY0101EN', 'ML0101ENv3', 'DS0321EN', 'BD0101EN', 'CC0101EN'}
# User 1188137: Recommended courses - {'PY0101EN', 'BD0111EN', 'DA0101EN', 'BD0211EN', 'CC0101EN', 'ML0103EN', 'RP0101EN'}
# User 1341177: Recommended courses - {'DA0101EN', 'DS0105EN', 'DS0101EN', 'DS0103EN'}
# User 883150: Recommended courses - {'BD0111EN', 'DA0101EN', 'BD0211EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 547966: Recommended courses - {'PY0101EN', 'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN'}
# User 973663: Recommended courses - {'BD0111EN', 'DS0101EN', 'DV0101EN', 'DA0101EN', 'ML0101ENv3', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 988115: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'CO0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'BD0115EN', 'CC0101EN', 'CB0103EN'}
# User 1304909: Recommended courses - {'BD0111EN', 'DS0101EN', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CO0301EN', 'BC0101EN', 'CC0103EN', 'CC0250EN'}
# User 1285846: Recommended courses - {'CC0101EN', 'ML0101ENv3', 'DV0101EN', 'DS0103EN'}
# User 142685: Recommended courses - {'BD0131EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0120ENv2', 'RP0101EN', 'ML0101EN', 'BD0111EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'SC0101EN', 'DS0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 182509: Recommended courses - {'DV0101EN', 'DS0105EN', 'BD0115EN', 'DS0103EN', 'ML0101EN'}
# User 1120306: Recommended courses - set()
# User 1167829: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'CO0201EN', 'CC0101EN', 'CC0103EN', 'CC0250EN'}
# User 1898770: Recommended courses - {'ML0151EN'}
# User 794282: Recommended courses - {'PY0101EN', 'DA0101EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 480186: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 2020759: Recommended courses - {'CO0101EN'}
# User 945917: Recommended courses - set()
# User 1291244: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'ML0151EN', 'RP0105EN', 'ML0101EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'WA0101EN', 'CL0101EN', 'ML0120EN', 'CO0101EN', 'SC0101EN', 'BD0115EN', 'CB0103EN'}
# User 1619917: Recommended courses - {'ML0115EN', 'BD0101EN', 'ML0101ENv3', 'BD0111EN'}
# User 628701: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'BC0101EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN'}
# User 1296757: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1069367: Recommended courses - {'PY0101EN', 'DS0101EN', 'CC0101EN', 'WA0101EN', 'CO0101EN'}
# User 1676451: Recommended courses - set()
# User 897866: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0211EN', 'BD0143EN'}
# User 1691129: Recommended courses - {'ML0115EN', 'CB0103EN', 'BD0111EN', 'DS0103EN'}
# User 1607405: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1251998: Recommended courses - {'CC0201EN', 'CC0101EN', 'CC0103EN', 'BC0101EN'}
# User 1259123: Recommended courses - set()
# User 1813726: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1697791: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN'}
# User 1121817: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'DS0103EN'}
# User 940704: Recommended courses - set()
# User 728690: Recommended courses - {'DV0101EN', 'ML0115EN', 'ML0101ENv3', 'ST0101EN', 'ML0101EN'}
# User 931463: Recommended courses - {'DV0101EN', 'DS0101EN', 'DS0105EN', 'ML0101ENv3', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DS0103EN', 'DB0101EN'}
# User 1180992: Recommended courses - {'BD0111EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CC0101EN', 'CO0201EN', 'CO0301EN', 'CO0101EN', 'CC0103EN', 'CC0250EN'}
# User 1831780: Recommended courses - {'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 555836: Recommended courses - {'PY0101EN', 'DA0101EN', 'DS0105EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 702927: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0115EN', 'ST0101EN', 'DS0103EN'}
# User 1438699: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'BD0101EN', 'ML0151EN', 'DS0103EN'}
# User 624248: Recommended courses - {'ML0151EN', 'DS0105EN', 'DV0151EN', 'DS0103EN'}
# User 1893628: Recommended courses - {'ML0122ENv1', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'ML0120ENv2', 'DB0101EN'}
# User 699014: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1608895: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'ST0101EN', 'DS0103EN'}
# User 968280: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'DE0205EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 2057052: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1312255: Recommended courses - {'RP0101EN'}
# User 435051: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'DA0101EN', 'CC0101EN', 'DS0103EN', 'CB0103EN'}
# User 1300715: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 515823: Recommended courses - {'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN'}
# User 1382697: Recommended courses - {'PY0101EN', 'BD0111EN', 'CC0103EN', 'DS0101EN', 'BD0211EN', 'BD0101EN', 'CC0101EN', 'CL0101EN', 'BC0101EN', 'CC0250EN'}
# User 1008779: Recommended courses - {'ML0115EN', 'BD0101EN', 'ML0101ENv3', 'BD0111EN'}
# User 1167173: Recommended courses - {'BD0111EN', 'DS0101EN', 'DV0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'DS0103EN', 'DB0101EN'}
# User 243266: Recommended courses - {'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN'}
# User 888995: Recommended courses - set()
# User 503032: Recommended courses - {'PY0101EN', 'BD0123EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'CC0101EN', 'ML0103EN', 'CB0103EN'}
# User 406940: Recommended courses - {'PY0101EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'CO0301EN', 'CL0101EN', 'BC0101EN', 'CO0101EN', 'CC0103EN', 'ML0120EN', 'DA0101EN', 'CC0101EN', 'CB0103EN'}
# User 2061096: Recommended courses - {'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN'}
# User 149690: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1236864: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0212EN', 'BD0121EN', 'BD0143EN'}
# User 621497: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0111EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1813704: Recommended courses - {'PY0101EN', 'BD0141EN', 'BD0131EN', 'DS0105EN', 'RP0101EN'}
# User 2082818: Recommended courses - {'PY0101EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'CC0101EN', 'DS0103EN', 'CB0103EN'}
# User 828900: Recommended courses - {'SC0101EN', 'BD0131EN', 'PY0101EN', 'BD0115EN'}
# User 609057: Recommended courses - {'PY0101EN', 'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 1170761: Recommended courses - {'PY0101EN', 'BD0111EN', 'CC0101EN', 'WA0101EN', 'CO0101EN'}
# User 927022: Recommended courses - {'DS0101EN', 'ML0101ENv3', 'DS0105EN', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 1607052: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0115EN', 'ST0101EN', 'WA0101EN'}
# User 641270: Recommended courses - set()
# User 591984: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1864557: Recommended courses - {'BD0101EN', 'BD0111EN', 'DS0101EN'}
# User 459415: Recommended courses - {'BD0101EN', 'DV0101EN', 'DB0101EN', 'PA0101EN'}
# User 1758635: Recommended courses - {'BD0101EN', 'BD0111EN', 'DS0101EN', 'ML0120ENv2'}
# User 630417: Recommended courses - {'PY0101EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 922932: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'ML0151EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'CO0301EN', 'CC0103EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'CB0103EN'}
# User 944182: Recommended courses - {'BC0201EN'}
# User 528259: Recommended courses - {'ML0115EN', 'ST0101EN'}
# User 1031032: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 753356: Recommended courses - {'PY0101EN', 'DV0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'DS0103EN'}
# User 446982: Recommended courses - {'PY0101EN', 'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 902617: Recommended courses - {'BD0111EN'}
# User 1667543: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CO0201EN', 'CO0301EN', 'CO0101EN', 'CL0101EN', 'BC0101EN', 'CC0250EN'}
# User 572721: Recommended courses - {'ML0115EN', 'BD0101EN', 'DV0101EN'}
# User 992171: Recommended courses - {'RP0101EN', 'DS0301EN', 'DS0101EN', 'DS0103EN'}
# User 2036996: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 315714: Recommended courses - {'PY0101EN'}
# User 2052832: Recommended courses - {'BD0111EN', 'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 639271: Recommended courses - {'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 1818149: Recommended courses - set()
# User 569284: Recommended courses - {'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0143EN'}
# User 982945: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0115EN', 'BD0121EN', 'BD0143EN'}
# User 1660009: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'BD0211EN', 'CO0201EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'BD0115EN', 'CC0101EN'}
# User 425952: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0141EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 910687: Recommended courses - {'DV0151EN'}
# User 934060: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 1455717: Recommended courses - {'DA0101EN', 'DV0101EN', 'CO0101EN'}
# User 1469379: Recommended courses - {'BC0201EN'}
# User 418401: Recommended courses - {'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 700521: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'ML0120ENv2', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'BD0115EN', 'CC0101EN', 'CB0103EN'}
# User 544738: Recommended courses - {'BD0212EN', 'PY0101EN', 'BD0121EN', 'SC0101EN'}
# User 1396750: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'DS0103EN', 'BC0101EN'}
# User 765007: Recommended courses - {'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 1085627: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0101EN'}
# User 779324: Recommended courses - {'BD0101EN', 'ML0101ENv3', 'ML0120ENv2'}
# User 1390701: Recommended courses - {'BD0101EN', 'BD0111EN', 'DS0101EN', 'ML0120ENv2'}
# User 776333: Recommended courses - set()
# User 1581286: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1803286: Recommended courses - {'ML0122ENv1', 'ST0101EN', 'BD0101EN', 'ML0120ENv2', 'RP0101EN', 'DB0101EN'}
# User 70434: Recommended courses - {'PY0101EN', 'BD0123EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1190408: Recommended courses - set()
# User 620994: Recommended courses - {'DV0101EN', 'ML0115EN', 'DA0101EN', 'ML0122ENv1', 'ML0101ENv3', 'DS0105EN', 'PA0101EN', 'RP0101EN', 'ML0120ENv2', 'DB0101EN'}
# User 1051928: Recommended courses - {'RP0101EN', 'CC0101EN', 'PY0101EN', 'BD0111EN'}
# User 960871: Recommended courses - {'RP0101EN', 'WA0101EN', 'BD0111EN', 'CO0101EN'}
# User 1101622: Recommended courses - {'BD0111EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 964624: Recommended courses - {'SC0101EN', 'BD0141EN', 'BD0212EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1950381: Recommended courses - set()
# User 497451: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN', 'BC0101EN'}
# User 1128883: Recommended courses - {'ST0101EN'}
# User 52091: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0151EN', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'BC0101EN', 'SC0101EN', 'DS0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN'}
# User 2050073: Recommended courses - {'BD0101EN', 'DS0105EN', 'BD0111EN', 'DS0103EN'}
# User 757762: Recommended courses - {'BD0212EN', 'BD0143EN', 'BD0121EN', 'DS0101EN'}
# User 1717953: Recommended courses - set()
# User 733707: Recommended courses - {'RP0101EN', 'DS0105EN', 'DS0103EN'}
# User 739171: Recommended courses - {'BD0143EN', 'BD0212EN', 'SC0101EN'}
# User 1443238: Recommended courses - {'DV0101EN', 'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'BD0101EN'}
# User 1021113: Recommended courses - {'PY0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1255885: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'CC0201EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'ML0122ENv1', 'ST0101EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 899011: Recommended courses - {'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 1574761: Recommended courses - {'DA0101EN', 'CC0101EN', 'BD0111EN', 'BD0211EN'}
# User 1194104: Recommended courses - {'LB0107ENv1'}
# User 1562232: Recommended courses - {'BD0111EN', 'DS0101EN', 'DV0101EN', 'ML0115EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 615039: Recommended courses - {'PY0101EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN'}
# User 1738888: Recommended courses - {'DS0101EN', 'ML0115EN', 'DS0105EN', 'BD0211EN', 'BD0115EN', 'ST0101EN', 'DS0103EN', 'ML0101EN'}
# User 1803965: Recommended courses - set()
# User 606892: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0115EN', 'DS0103EN', 'RP0101EN'}
# User 1131617: Recommended courses - set()
# User 1008504: Recommended courses - {'DV0101EN', 'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'CC0101EN', 'DS0103EN'}
# User 440679: Recommended courses - {'DS0105EN', 'DV0101EN', 'BD0211EN'}
# User 681785: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'CO0301EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'CB0103EN'}
# User 1062761: Recommended courses - set()
# User 428830: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0212EN', 'BD0211EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 925383: Recommended courses - {'CC0101EN', 'CC0103EN'}
# User 1104367: Recommended courses - {'CC0201EN', 'CC0101EN', 'CC0103EN'}
# User 1371316: Recommended courses - {'BD0111EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'BD0101EN'}
# ...
# User 1396267: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0101ENv3', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'DS0103EN'}
# User 978279: Recommended courses - {'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DB0101EN'}
# User 917017: Recommended courses - {'DV0101EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0101EN', 'DS0103EN'}
# User 1151828: Recommended courses - {'CO0201EN', 'CC0101EN', 'CO0301EN', 'CL0101EN'}
# User 1049471: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0101ENv3', 'CC0201EN', 'BD0101EN', 'CC0101EN', 'CO0301EN', 'BC0101EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1730573: Recommended courses - {'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'DS0105EN', 'BD0101EN', 'DB0101EN'}
# User 1380474: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN', 'BC0101EN'}
# User 979599: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'RP0101EN'}
# User 1858250: Recommended courses - {'PY0101EN', 'BD0111EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 1139362: Recommended courses - {'BD0111EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'BD0211EN', 'BD0101EN', 'CC0101EN', 'DS0103EN'}
# User 921445: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1679018: Recommended courses - {'CC0101EN', 'CC0150EN', 'CC0103EN'}
# User 896192: Recommended courses - {'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'RP0105EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'DE0205EN', 'DS0105EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN'}
# User 704583: Recommended courses - {'PY0101EN', 'BD0111EN', 'DV0101EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0115EN', 'DS0103EN'}
# User 161471: Recommended courses - {'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'CC0101EN', 'CO0301EN', 'BC0101EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 896335: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'DS0301EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 2000341: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 373076: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1699606: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'DV0101EN', 'ML0115EN', 'DS0105EN', 'BD0101EN', 'DS0103EN'}
# User 1239926: Recommended courses - {'DS0105EN', 'DS0101EN', 'DS0103EN'}
# User 1132916: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'WA0101EN'}
# User 606214: Recommended courses - {'DS0105EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 1545628: Recommended courses - {'BD0111EN', 'DS0105EN', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 1238107: Recommended courses - {'BD0111EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 1499966: Recommended courses - {'ML0101ENv3', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 1919984: Recommended courses - {'BD0111EN', 'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 1063521: Recommended courses - {'BD0111EN', 'ML0115EN', 'CO0301EN', 'CC0101EN', 'DS0103EN'}
# User 2056704: Recommended courses - {'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 762066: Recommended courses - {'PY0101EN', 'DV0101EN', 'BD0111EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'DS0103EN'}
# User 1304559: Recommended courses - {'PY0101EN', 'DV0101EN', 'ML0115EN', 'DA0101EN', 'ML0101ENv3'}
# User 1717303: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0212EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'WA0101EN', 'DB0101EN'}
# User 1799705: Recommended courses - {'BD0111EN', 'DS0101EN', 'BD0211EN', 'CO0201EN', 'BD0101EN', 'CO0301EN', 'CL0101EN', 'BC0101EN', 'CO0101EN'}
# User 720149: Recommended courses - {'BD0111EN', 'DS0101EN', 'CC0101EN', 'RP0101EN', 'CO0101EN'}
# User 503291: Recommended courses - {'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'ST0101EN', 'DB0101EN'}
# User 1234087: Recommended courses - {'SC0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'WA0101EN', 'DB0101EN'}
# User 646861: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0131EN', 'BD0121EN', 'BD0143EN'}
# User 1194859: Recommended courses - {'BD0212EN', 'PY0101EN', 'DS0101EN', 'SC0101EN'}
# User 889265: Recommended courses - set()
# User 1616648: Recommended courses - {'DV0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'DS0103EN'}
# User 1196755: Recommended courses - {'BD0101EN', 'BD0111EN', 'DS0101EN', 'ML0120ENv2'}
# User 1328233: Recommended courses - {'DS0101EN', 'DS0105EN', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'RP0101EN', 'DS0301EN', 'DS0103EN', 'DB0101EN'}
# User 911789: Recommended courses - {'PY0101EN', 'BD0123EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1897898: Recommended courses - {'BD0111EN', 'DS0101EN', 'DV0101EN', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 673206: Recommended courses - {'PY0101EN', 'ML0101ENv3', 'ML0120ENv2'}
# User 937026: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'WA0101EN', 'DB0101EN'}
# User 1493943: Recommended courses - {'PY0101EN', 'DA0101EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 1194346: Recommended courses - {'PY0101EN', 'DV0101EN', 'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'DB0101EN'}
# User 1000886: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN'}
# User 1889420: Recommended courses - {'DV0101EN', 'BD0111EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN'}
# User 1978886: Recommended courses - {'BD0101EN', 'PY0101EN', 'BD0111EN'}
# User 1627236: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CO0401EN', 'DB0101EN', 'BD0212EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'BC0101EN', 'CO0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 732897: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0121EN'}
# User 1287646: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 1124048: Recommended courses - {'CC0101EN', 'CC0150EN', 'CC0103EN'}
# User 676317: Recommended courses - {'ML0115EN', 'RP0101EN', 'PY0101EN', 'DS0103EN'}
# User 486201: Recommended courses - {'DV0101EN', 'ML0115EN', 'DA0101EN', 'DS0105EN', 'DS0103EN'}
# User 506202: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'CB0103EN'}
# User 645459: Recommended courses - {'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'DB0101EN'}
# User 942261: Recommended courses - {'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 1278965: Recommended courses - {'CO0301EN', 'CO0401EN', 'BC0101EN'}
# User 891366: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'DV0101EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1955349: Recommended courses - {'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DB0101EN'}
# User 371091: Recommended courses - {'BD0111EN', 'DA0101EN', 'BD0211EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 1664399: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'ML0101ENv3', 'BD0101EN', 'ML0120ENv2'}
# User 1431881: Recommended courses - {'BD0111EN', 'ML0115EN', 'ML0101ENv3', 'DS0105EN', 'BD0101EN', 'DB0101EN'}
# User 1840749: Recommended courses - {'DS0101EN', 'ML0115EN', 'DS0105EN', 'ST0101EN', 'DS0103EN', 'DB0101EN'}
# User 746547: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0115EN', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'RP0101EN'}
# User 1781984: Recommended courses - {'PY0101EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'DV0101EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'DS0301EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DS0101EN', 'DA0101EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'CB0103EN'}
# User 1496810: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0211EN', 'CC0201EN', 'CO0301EN', 'BC0101EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1578866: Recommended courses - {'DS0101EN', 'ML0122ENv1', 'DS0105EN', 'PA0101EN', 'ST0101EN', 'BD0101EN', 'DS0301EN', 'DS0103EN', 'RP0101EN'}
# User 926743: Recommended courses - {'PY0101EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 1887480: Recommended courses - {'BD0111EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'ST0101EN', 'BD0101EN', 'DS0103EN', 'DB0101EN'}
# User 609064: Recommended courses - {'ML0101ENv3', 'BD0111EN', 'DS0101EN', 'ML0120ENv2'}
# User 728302: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'DB0101EN'}
# User 1646441: Recommended courses - {'CO0101EN'}
# User 731074: Recommended courses - {'PY0101EN', 'BD0111EN', 'DA0101EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'DS0103EN'}
# User 2032910: Recommended courses - {'BD0111EN', 'DS0105EN', 'BD0101EN', 'DS0103EN', 'CB0103EN'}
# User 1911140: Recommended courses - {'BD0111EN', 'ML0101ENv3', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'DS0103EN'}
# User 1256661: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0101ENv3', 'CO0201EN', 'CC0201EN', 'CC0101EN', 'CO0301EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1870948: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'CO0201EN', 'BD0211EN', 'BD0101EN', 'CO0301EN', 'CL0101EN'}
# User 1007060: Recommended courses - {'DV0101EN', 'ML0115EN', 'DA0101EN', 'ML0101ENv3', 'CO0301EN', 'DS0103EN', 'CO0101EN'}
# User 1758996: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ST0101EN', 'DS0103EN', 'DB0101EN'}
# User 720259: Recommended courses - {'PY0101EN', 'ML0101ENv3', 'DS0101EN', 'ML0120ENv2'}
# User 884472: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'DV0101EN', 'DA0101EN', 'DS0105EN', 'ML0101ENv3', 'BD0101EN', 'DS0103EN'}
# User 1116126: Recommended courses - {'PY0101EN', 'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CC0101EN', 'CO0301EN', 'CL0101EN', 'CC0103EN', 'CC0250EN'}
# User 1121636: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0101ENv3', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CO0201EN', 'CO0301EN', 'CO0101EN', 'CL0101EN', 'BC0101EN', 'CC0250EN'}
# User 576397: Recommended courses - {'DA0101EN', 'DS0105EN', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'ML0103EN', 'DS0103EN', 'RP0101EN'}
# User 1907898: Recommended courses - {'BD0111EN', 'DS0101EN', 'BD0211EN', 'CC0201EN', 'BD0101EN', 'CC0101EN', 'CO0201EN', 'CO0301EN', 'CL0101EN', 'BC0101EN', 'CC0250EN'}
# User 1390057: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0115EN', 'ST0101EN', 'RP0101EN', 'CB0103EN'}
# User 1021071: Recommended courses - {'BD0111EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN', 'ML0103EN', 'DS0301EN', 'RP0101EN'}
# User 625223: Recommended courses - {'BD0111EN', 'DS0101EN', 'ML0115EN', 'DS0105EN', 'ML0101ENv3', 'DS0103EN', 'DB0101EN'}
# User 1830259: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0115EN', 'WA0101EN'}
# User 676094: Recommended courses - {'PY0101EN', 'DV0101EN', 'ML0115EN', 'ML0101ENv3', 'ML0101EN'}
# User 1076538: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0101ENv3', 'DS0321EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'CC0101EN'}
# User 1871214: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1474724: Recommended courses - {'SC0101EN', 'PY0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1344813: Recommended courses - {'SC0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1847555: Recommended courses - {'PY0101EN', 'BD0123EN', 'BD0131EN', 'DS0321EN', 'DV0151EN', 'PA0101EN', 'CC0201EN', 'CO0401EN', 'DB0101EN', 'CNSC02EN', 'BD0212EN', 'DAI101EN', 'ML0101ENv3', 'BD0211EN', 'CO0201EN', 'ML0151EN', 'ML0120ENv2', 'RP0101EN', 'RP0105EN', 'ML0101EN', 'BC0201EN', 'BD0111EN', 'BD0141EN', 'ML0115EN', 'DE0205EN', 'ML0122ENv1', 'DS0105EN', 'ST0101EN', 'BD0101EN', 'CO0301EN', 'WA0101EN', 'CL0101EN', 'CC0103EN', 'CO0101EN', 'BC0101EN', 'ML0120EN', 'SC0101EN', 'DA0101EN', 'BD0115EN', 'CC0101EN', 'DS0103EN', 'CB0103EN'}
# User 1669829: Recommended courses - {'PY0101EN', 'BD0111EN', 'ML0115EN', 'BD0101EN', 'ML0120ENv2'}
# User 481658: Recommended courses - {'SC0101EN', 'PY0101EN', 'DS0101EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'BD0115EN', 'ST0101EN', 'WA0101EN', 'DB0101EN'}
# User 1341273: Recommended courses - {'BD0111EN', 'CC0103EN', 'DS0101EN', 'BD0211EN', 'BD0101EN', 'CC0101EN', 'CO0301EN', 'CL0101EN', 'BC0101EN', 'CC0250EN'}
# User 884271: Recommended courses - {'PY0101EN', 'DS0101EN', 'DS0105EN', 'DS0321EN', 'ML0101ENv3', 'BD0211EN', 'ST0101EN', 'CC0101EN', 'DS0103EN'}
# User 1868084: Recommended courses - {'CC0150EN', 'CC0103EN'}
# User 630511: Recommended courses - {'DS0101EN', 'BD0141EN', 'BD0212EN', 'BD0131EN', 'BD0211EN', 'ST0101EN', 'BD0101EN', 'WA0101EN', 'DB0101EN'}

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * First of all, create a `user_subset` of  `test_users_labelled` where `test_users_labelled['user'] == user_id`.
# * Get the enrolled courses by  simply accessing `['item']` column of `user_subset`
# * Find its cluster label by accessing `['cluster']` column of `user_subset`. You can just use the first one (`.iloc[0]`) since every value in the column is the same for an individual user.
# * You can find all courses in the same cluster, by simply accessing `['item']` column of a subset of `test_users_labelled` where `test_users_labelled[test_users_labelled['cluster'] == cluster_id]`
# * You can find new/unseen courses to the user by taking a set difference between courses in cluster and enrolled_courses by using `.difference` method (dont forget to convert 2 lists in to sets before calling the method).
# * Use `courses_cluster` data set to find popularity of new/unseen courses and make unseen and popular courses as recommendation results for the user
#
# </details>

# %% [markdown]
# With the recommendation results, you also need to write some analytic code to answer the following two questions:

# %% [markdown]
# - On average, how many new/unseen courses have been recommended to each user?
# - What are the most frequently recommended courses? Return the top-10 commonly recommended courses across all users.

# %% [markdown]
# For example, suppose we have only 3 test users, each user receives the following recommendations:

# %% [markdown]
# - User1: ['course1', 'course2']
# - User2: ['course3', 'course4']
# - User3: ['course3', 'course4', 'course5']

# %% [markdown]
# Then, the average recommended courses per user is $(2 + 2 + 3) / 3 = 2.33$. The top-2 recommended courses are: `course3`: 2 times, and `course4`: 2 times.

# %% [markdown]
# Note that the answers will depend on how you compute the popular courses for each cluster. A lower threshold yields more recommended courses but with smaller confidence so that some test users may receive very long course recommendation lists and feel overwhelmed.
#
# Ideally, we should limit the maximum course recommendations for each user to be less than 20 courses per user.

# %% [markdown]
# ### Explore other clustering algorithms

# %% [markdown]
# As you have learned in previous unsupervised learning course, there are many other clustering algorithms such as `DBSCAN` and `Hierarchical Clustering`. You are encouraged to try them on the user profile feature vectors and compare the results with K-means.

# %% [markdown]
# ### Summary

# %% [markdown]
# Congratulations! In this lab, you have applied clustering algorithms to group users with similar interests and also tried PCA to reduce the dimensions of user feature vectors.
#
# Furthermore, with each user finding its learning interest group, you have also implemented clustering-based course recommender system to make recommendations based on his/her group members' popular courses choices.
